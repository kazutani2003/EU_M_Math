# %% [markdown]
# <a href="https://colab.research.google.com/github/kazutani2003/EU_M_Math/blob/main/Chap02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

np.random.uniform(0.0,1.0,10000)
# Out:
# array([0.00913944, 0.52857909, 0.98873646, ..., 0.05987995, 0.19236686,
#        0.33022855])

# %%
import numpy as np
import math

np.random.uniform(0.0, 1.0, 10000)

num_sumple = 10000

x = np.random.uniform(0.0 , 1.0 , num_sumple)
y = np.random.uniform(0.0 , 1.0 , num_sumple)

x_in = []
y_in = []
x_out = []
y_out = []

count_in = 0
for i in range(num_sumple):
  r = math.hypot(x[i], y[i])

  if r <= 1.0:
    count_in += 1
    x_in.append(x[i])
    y_in.append(y[i])
  else:
    x_out.append(x[i])
    y_out.append(y[i])

print(count_in)
# Out:
# 7867

# %%
import numpy as np
import math

np.random.uniform(0.0, 1.0, 10000)

num_sumple = 10000

x = np.random.uniform(0.0 , 1.0 , num_sumple)
y = np.random.uniform(0.0 , 1.0 , num_sumple)

x_in = []
y_in = []
x_out = []
y_out = []

count_in = 0
for i in range(num_sumple):
  r = math.hypot(x[i], y[i])

  if r <= 1.0:
    count_in += 1
    x_in.append(x[i])
    y_in.append(y[i])
  else:
    x_out.append(x[i])
    y_out.append(y[i])

pi = 4 * count_in/num_sumple
print(pi)
# Out:
# 3.1356
