# %% [markdown]
# <a href="https://colab.research.google.com/github/kazutani2003/EU_M_Math/blob/main/Chap04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 練習問題4-13

# %%
import requests, zipfile
from io import StringIO
import io

url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00356/student.zip'
r = requests.get(url, stream=True)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()

# %%
import pandas as pd
from scipy import stats

mat_df = pd.read_csv('student-mat.csv', sep=';')
por_df = pd.read_csv('student-por.csv', sep=';')
mat_g2 = mat_df['G2']
por_g2 = por_df['G2']

# %%
mean_mat_g2 = mat_g2.mean()
mean_por_g2 = por_g2.mean()

print(f"数学のG2成績の平均: {mean_mat_g2:.2f}")
print(f"ポルトガル語のG2成績の平均: {mean_por_g2:.2f}")

statistic, p_value = stats.ttest_ind(mat_g2, por_g2, equal_var=False)

print(f"T統計値: {statistic:.3f}")
print(f"p値: {p_value:.3f}")
# Out:
# 数学のG2成績の平均: 10.71
# ポルトガル語のG2成績の平均: 11.57
# T統計値: -3.872
# p値: 0.000

# %% [markdown]
# 総合問題問題4-1

# %% [markdown]
# 欠席数

# %%
import pandas as pd
from scipy import stats

mat_df = pd.read_csv('student-mat.csv', sep=';')
por_df = pd.read_csv('student-por.csv', sep=';')
mat_g2 = mat_df['absences']
por_g2 = por_df['absences']

# %%
print("欠席数の差（平均）:", mat_df['absences'].mean() - por_df['absences'].mean())
# Out:
# 欠席数の差（平均）: 2.0493846423904354

# %% [markdown]
# 勉強時間

# %%
import pandas as pd
from scipy import stats

mat_df = pd.read_csv('student-mat.csv', sep=';')
por_df = pd.read_csv('student-por.csv', sep=';')
mat_g2 = mat_df['study time']
por_g2 = por_df['study time']

# %%
print("勉強時間の差（平均）:", mat_df['studytime'].mean() - por_df['studytime'].mean())
# Out:
# 勉強時間の差（平均）: 0.10478048019348196
